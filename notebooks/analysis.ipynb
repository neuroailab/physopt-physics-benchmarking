# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('physopt_results.csv')
print (df.head())
df_old = pd.read_csv('physopt_results_old.csv')
print (df_old.head())
# Out:
#    Seed                Model Model Train Data Readout Train Data  \
# 0     0  SVGPretrainedFrozen         dominoes           dominoes
# 1     0  SVGPretrainedFrozen         dominoes           dominoes
# 2     0  SVGPretrainedFrozen         dominoes           dominoes
# 3     0  SVGPretrainedFrozen         dominoes           dominoes
# 4     0  SVGPretrainedFrozen             drop               drop
#
#   Readout Test Data  Train Accuracy  Test Accuracy Readout Type  \
# 0          dominoes        0.765748       0.553571            A
# 1          dominoes        0.796260       0.383929            B
# 2          dominoes        0.646654       0.544643            C
# 3          dominoes        0.646654       0.544643            D
# 4              drop        0.971910       0.609375            A
#
#    Sequence Length  Readout Train Positive  Readout Train Negative  \
# 0              150                   508.0                   482.0
# 1              150                   508.0                   482.0
# 2              150                   508.0                   482.0
# 3               30                   508.0                   482.0
# 4              150                   534.0                   466.0
#
#    Readout Test Positive  Readout Test Negative  \
# 0                   56.0                   34.0
# 1                   56.0                   34.0
# 2                   56.0                   34.0
# 3                   56.0                   34.0
# 4                   36.0                   64.0
#
#                                          Description
# 0  entire sequence visually encoded, label over e...
# 1  seen frames visually encoded, unseen frames pr...
# 2  seen visual frames visually encoded, unseen fr...
# 3  seen frames visually encoded, unseen frames ig...
# 4  entire sequence visually encoded, label over e...
#    Seed                    Model Model Train Data Readout Train Data  \
# 0     0  SVGPretrainedFrozenDEIT              all          rollslide
# 1     0  SVGPretrainedFrozenDEIT              all          rollslide
# 2     0  SVGPretrainedFrozenDEIT              all          rollslide
# 3     0  SVGPretrainedFrozenDEIT              all          rollslide
# 4     0  SVGPretrainedFrozenDEIT              all             towers
#
#   Readout Test Data  Train Accuracy  Test Accuracy Readout Type  \
# 0         rollslide        0.990534       0.737288            A
# 1         rollslide        0.984509       0.686441            B
# 2         rollslide        0.987091       0.703390            C
# 3         rollslide        0.987091       0.703390            D
# 4            towers        0.961183       0.767241            A
#
#    Sequence Length  Readout Train Positive  Readout Train Negative  \
# 0              150                   581.0                   417.0
# 1              150                   581.0                   417.0
# 2              150                   581.0                   417.0
# 3               30                   581.0                   417.0
# 4              150                   541.0                   459.0
#
#    Readout Test Positive  Readout Test Negative  \
# 0                   39.0                   59.0
# 1                   39.0                   59.0
# 2                   39.0                   59.0
# 3                   39.0                   59.0
# 4                   40.0                   58.0
#
#                                          Description
# 0  entire sequence visually encoded, label over e...
# 1  seen frames visually encoded, unseen frames pr...
# 2  seen visual frames visually encoded, unseen fr...
# 3  seen frames visually encoded, unseen frames ig...
# 4  entire sequence visually encoded, label over e...

# %%
df[df['Model']=='OP3']
# Out:
#      Seed Model Model Train Data Readout Train Data Readout Test Data  \
# 256     0   OP3              all          rollslide         rollslide
# 257     0   OP3              all          rollslide         rollslide
# 258     0   OP3              all          rollslide         rollslide
# 259     0   OP3              all          collision         collision
# 260     0   OP3              all          collision         collision
# 261     0   OP3              all          collision         collision
# 262     0   OP3              all               drop              drop
# 263     0   OP3              all               drop              drop
# 264     0   OP3              all               drop              drop
# 265     0   OP3              all              cloth             cloth
# 266     0   OP3              all              cloth             cloth
# 267     0   OP3              all              cloth             cloth
# 268     0   OP3              all        containment       containment
# 269     0   OP3              all        containment       containment
# 270     0   OP3              all        containment       containment
# 271     0   OP3         dominoes           dominoes          dominoes
# 272     0   OP3         dominoes           dominoes          dominoes
# 273     0   OP3         dominoes           dominoes          dominoes
# 274     0   OP3             drop               drop              drop
# 275     0   OP3             drop               drop              drop
# 276     0   OP3             drop               drop              drop
# 277     0   OP3      containment        containment       containment
# 278     0   OP3      containment        containment       containment
# 279     0   OP3      containment        containment       containment
# 280     0   OP3           towers             towers            towers
# 281     0   OP3           towers             towers            towers
# 282     0   OP3           towers             towers            towers
# 283     0   OP3        collision          collision         collision
# 284     0   OP3        collision          collision         collision
# 285     0   OP3        collision          collision         collision
# 286     0   OP3            cloth              cloth             cloth
# 287     0   OP3            cloth              cloth             cloth
# 288     0   OP3            cloth              cloth             cloth
# 289     0   OP3        rollslide          rollslide         rollslide
# 290     0   OP3        rollslide          rollslide         rollslide
# 291     0   OP3        rollslide          rollslide         rollslide
# 292     0   OP3          linking            linking           linking
# 293     0   OP3          linking            linking           linking
# 294     0   OP3          linking            linking           linking
#
#      Train Accuracy  Test Accuracy Readout Type  Sequence Length  \
# 256        0.929860       0.517241            A              150
# 257        0.939880       0.525862            B              150
# 258        0.937876       0.525862            C              150
# 259        0.883813       0.410000            A              150
# 260        0.885799       0.420000            B              150
# 261        0.887786       0.450000            C              150
# 262        0.894895       0.515873            A              150
# 263        0.893894       0.500000            B              150
# 264        0.892893       0.492063            C              150
# 265        1.000000       0.520408            A              150
# 266        1.000000       0.520408            B              150
# 267        0.744489       0.448980            C              150
# 268        0.895000       0.530000            A              150
# 269        0.890000       0.480000            B              150
# 270        0.892000       0.440000            C              150
# 271        0.896482       0.600000            A              150
# 272        0.882412       0.600000            B              150
# 273        0.894472       0.558333            C              150
# 274        0.894895       0.515873            A              150
# 275        0.903904       0.484127            B              150
# 276        0.903904       0.515873            C              150
# 277        0.906000       0.550000            A              150
# 278        0.904000       0.570000            B              150
# 279        0.904000       0.570000            C              150
# 280        0.913000       0.456897            A              150
# 281        0.905000       0.448276            B              150
# 282        0.916000       0.456897            C              150
# 283        0.879841       0.450000            A              150
# 284        0.895730       0.450000            B              150
# 285        0.898709       0.450000            C              150
# 286        0.666667       0.510204            A              150
# 287        0.666667       0.510204            B              150
# 288        0.666667       0.510204            C              150
# 289        0.933868       0.439655            A              150
# 290        0.934870       0.517241            B              150
# 291        0.936874       0.474138            C              150
# 292        0.925000       0.472222            A              150
# 293        0.908000       0.472222            B              150
# 294        0.912000       0.481481            C              150
#
#      Readout Train Positive  Readout Train Negative  Readout Test Positive  \
# 256                     NaN                     NaN                    NaN
# 257                     NaN                     NaN                    NaN
# 258                     NaN                     NaN                    NaN
# 259                     NaN                     NaN                    NaN
# 260                     NaN                     NaN                    NaN
# 261                     NaN                     NaN                    NaN
# 262                     NaN                     NaN                    NaN
# 263                     NaN                     NaN                    NaN
# 264                     NaN                     NaN                    NaN
# 265                     NaN                     NaN                    NaN
# 266                     NaN                     NaN                    NaN
# 267                     NaN                     NaN                    NaN
# 268                     NaN                     NaN                    NaN
# 269                     NaN                     NaN                    NaN
# 270                     NaN                     NaN                    NaN
# 271                     NaN                     NaN                    NaN
# 272                     NaN                     NaN                    NaN
# 273                     NaN                     NaN                    NaN
# 274                     NaN                     NaN                    NaN
# 275                     NaN                     NaN                    NaN
# 276                     NaN                     NaN                    NaN
# 277                     NaN                     NaN                    NaN
# 278                     NaN                     NaN                    NaN
# 279                     NaN                     NaN                    NaN
# 280                     NaN                     NaN                    NaN
# 281                     NaN                     NaN                    NaN
# 282                     NaN                     NaN                    NaN
# 283                     NaN                     NaN                    NaN
# 284                     NaN                     NaN                    NaN
# 285                     NaN                     NaN                    NaN
# 286                     NaN                     NaN                    NaN
# 287                     NaN                     NaN                    NaN
# 288                     NaN                     NaN                    NaN
# 289                     NaN                     NaN                    NaN
# 290                     NaN                     NaN                    NaN
# 291                     NaN                     NaN                    NaN
# 292                     NaN                     NaN                    NaN
# 293                     NaN                     NaN                    NaN
# 294                     NaN                     NaN                    NaN
#
#      Readout Test Negative Description
# 256                    NaN         NaN
# 257                    NaN         NaN
# 258                    NaN         NaN
# 259                    NaN         NaN
# 260                    NaN         NaN
# 261                    NaN         NaN
# 262                    NaN         NaN
# 263                    NaN         NaN
# 264                    NaN         NaN
# 265                    NaN         NaN
# 266                    NaN         NaN
# 267                    NaN         NaN
# 268                    NaN         NaN
# 269                    NaN         NaN
# 270                    NaN         NaN
# 271                    NaN         NaN
# 272                    NaN         NaN
# 273                    NaN         NaN
# 274                    NaN         NaN
# 275                    NaN         NaN
# 276                    NaN         NaN
# 277                    NaN         NaN
# 278                    NaN         NaN
# 279                    NaN         NaN
# 280                    NaN         NaN
# 281                    NaN         NaN
# 282                    NaN         NaN
# 283                    NaN         NaN
# 284                    NaN         NaN
# 285                    NaN         NaN
# 286                    NaN         NaN
# 287                    NaN         NaN
# 288                    NaN         NaN
# 289                    NaN         NaN
# 290                    NaN         NaN
# 291                    NaN         NaN
# 292                    NaN         NaN
# 293                    NaN         NaN
# 294                    NaN         NaN

# %%
unique_models = np.unique(df['Model'])
plt.figure(figsize=(20,20))
for i, mdl in enumerate(unique_models):
    plt.subplot(4,4,i+1+(4*(i//4)))
    plt.title('Test Accuracy: ' + mdl)
    tmp_df = df[df['Model']==mdl]
    plt.scatter(tmp_df['Readout Type'], tmp_df['Test Accuracy'])
    plt.xlabel('Readout Type')
    plt.ylabel('Test Accuracy (%)')
    diff_df = tmp_df[df['Readout Type']=='B']['Test Accuracy'].values - tmp_df[df['Readout Type']=='C']['Test Accuracy'].values
    plt.subplot(4,4,i+5+(4*(i//4)))
    plt.hist(100*diff_df, bins=10, range=(-10, 10))
    plt.xlabel('Acc. diff (%): B - C')
    plt.ylabel('Count')
# Out:
# <ipython-input-62-008b6a2ccd1a>:10: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   diff_df = tmp_df[df['Readout Type']=='B']['Test Accuracy'].values - tmp_df[df['Readout Type']=='C']['Test Accuracy'].values

# %%
plt.figure(figsize=(20,20))
tmp_df = df[df['Model']=='SVGPretrainedFrozenDEIT']
plt.subplot(2,2,1)
plt.title('SVGPretrainedFrozenDEIT (more C\'s)')
plt.scatter(tmp_df['Readout Type'], tmp_df['Test Accuracy'])
plt.xlabel('Readout Type')
plt.ylabel('Test Accuracy (%)')
diff_df = tmp_df[tmp_df['Readout Type']=='B']['Test Accuracy'].values - tmp_df[tmp_df['Readout Type']=='C']['Test Accuracy'].values
plt.subplot(2,2,3)
plt.hist(100*diff_df, bins=10, range=(-10, 10))
plt.xlabel('Acc. diff (%): B - C')
plt.ylabel('Count')

tmp_df = df_old[df_old['Model']=='SVGPretrainedFrozenDEIT']
plt.subplot(2,2,2)
plt.title('SVGPretrainedFrozenDEIT (fewer C\'s)')
plt.scatter(tmp_df['Readout Type'], tmp_df['Test Accuracy'])
plt.xlabel('Readout Type')
plt.ylabel('Test Accuracy (%)')
diff_df = tmp_df[tmp_df['Readout Type']=='B']['Test Accuracy'].values - tmp_df[tmp_df['Readout Type']=='C']['Test Accuracy'].values
plt.subplot(2,2,4)
plt.hist(100*diff_df, bins=10, range=(-10, 10))
plt.xlabel('Acc. diff (%): B - C')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')
