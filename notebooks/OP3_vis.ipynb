# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
% matplotlib inline
img = mpimg.imread('/data1/eliwang/physopt-debug/OP3/collide/0/model/03-02-human-collide-1/03-02-human_collide_1_2021_03_02_07_47_51_0000--s-0/train_26.png') # 33, 35, 38
plt.figure(figsize=(20,20))
plt.imshow(img)
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
% matplotlib inline
img = mpimg.imread('/data1/eliwang/physopt-debug/OP3/collide/0/model/03-02-human-collide-1/03-02-human_collide_1_2021_03_02_05_12_45_0000--s-0/train_33.png')
plt.figure(figsize=(20,20))
plt.imshow(img)
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
% matplotlib inline
img = mpimg.imread('//data1/eliwang/physopt-debug/OP3/collide/0/model/03-05-human-collide-1/03-05-human_collide_1_2021_03_05_17_43_49_0000--s-0/train_6.png') # 2, 4
plt.figure(figsize=(20,20))
plt.imshow(img)
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
% matplotlib inline
img = mpimg.imread('/data1/eliwang/physopt-debug/OP3/collide/0/model/03-02-human-collide-1/03-02-human_collide_1_2021_03_02_05_12_45_0000--s-0/seed.png')
plt.figure(figsize=(20,20))
plt.imshow(img)
plt.show()
